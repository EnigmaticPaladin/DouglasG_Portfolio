# %% [markdown]
# UN FAO FOOD SECURITY PROJECT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
FoodSec = pd.read_csv("UNFAOFOODSEC Dataset 2023.csv")

# %%
FoodSec
# Out:
#        Domain Code                             Domain  Area Code (M49)  \
# 0               FS  Suite of Food Security Indicators                4
# 1               FS  Suite of Food Security Indicators                4
# 2               FS  Suite of Food Security Indicators                4
# 3               FS  Suite of Food Security Indicators                4
# 4               FS  Suite of Food Security Indicators                4
# ...            ...                                ...              ...
# 167003          FS  Suite of Food Security Indicators              716
# 167004          FS  Suite of Food Security Indicators              716
# 167005          FS  Suite of Food Security Indicators              716
# 167006          FS  Suite of Food Security Indicators              716
# 167007          FS  Suite of Food Security Indicators              716
#
#                Area  Element Code Element Item Code  \
# 0       Afghanistan          6121   Value     21010
# ...
